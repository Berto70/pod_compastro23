# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_01 = np.load('./data/ass_3/dt_0.01.npz')
#x1, y1, x2, y2, E

# %%
data = data_01['Euler_base']

# %%
plt.plot(data[:, 0], data[:, 1])
plt.plot(data[:, 2], data[:, 3])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# Create a 2x2 grid of subplots
fig = plt.figure(figsize=(8, 8))
gs = GridSpec(2, 2)

# Create subplot 1
ax1 = plt.subplot(gs[0, 0])
ax1.plot([0, 1], [0, 1])
ax1.set_title('Subplot 1')

# Create subplot 2
ax2 = plt.subplot(gs[0, 1])
ax2.plot([0, 1], [0, 1])
ax2.set_title('Subplot 2')

# Leave the third subplot empty
# This can be achieved by using the colspan parameter
ax3 = plt.subplot(gs[1, :])
ax3.axis('off')  # Turn off the axes for the empty subplot
ax3.set_title('Empty Subplot')

# Create subplot 4
ax4 = plt.subplot(gs[1, 1])
ax4.plot([0, 1], [0, 1])
ax4.set_title('Subplot 4')

plt.tight_layout()
plt.show()
