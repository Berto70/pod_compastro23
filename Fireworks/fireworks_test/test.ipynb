# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pos_i = np.load('./data/ass_3/pos_i.npy', allow_pickle=True)
pos_i.shape # -> (5, 406, 2, 3) -> (integrator, tsteps, particles, xyz)
# Out:
# (2, 3)

# %%
pos_i
# Out:
# array([[ 271.89341227,   43.75129911,    0.        ],
#        [-541.78682454,  -87.50259822,    0.        ]])

# %%
pos_i[0,:,:,0]
# Out:
# array([[  30.58260605,  -59.16521211],
#        [  30.58531447,  -59.17062894],
#        [  30.58802287,  -59.17604574],
#        ...,
#        [  57.95932609, -113.91865217],
#        [  57.96196934, -113.92393869],
#        [  57.9646126 , -113.92922519]])

# %%
plt.plot(pos_i[0,:,:,2], pos_i[0,:,:,0])
#plt.plot(pos_i[4][:][:][0], pos_i[4][:][:][1], color='red')
plt.show()
