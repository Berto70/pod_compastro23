# %%
import pandas as pd

df = pd.read_csv('./data_dict.csv')

# %%
df
# Out:
#       integrator  tstep  param  \
# 0     Euler_base      1      0
# 1     Euler_base      1      1
# 2     Euler_base      1      2
# 3     Euler_base      1      3
# 4     Euler_base      1      4
# ...          ...    ...    ...
# 2025         RK4      1    401
# 2026         RK4      1    402
# 2027         RK4      1    403
# 2028         RK4      1    404
# 2029         RK4      1    405
#
#                                                     pos  \
# 0     [[ 0.         -0.51639778  0.        ]\n [ 2. ...
# 1     [[ 0.25       -1.03279556  0.        ]\n [ 1.5...
# 2     [[ 0.62352647 -1.45351014  0.        ]\n [ 0.7...
# 3     [[ 1.03057014 -1.79114532  0.        ]\n [-0.0...
# 4     [[ 1.43917269 -2.07625772  0.        ]\n [-0.8...
# ...                                                 ...
# 2025  [[  635.2929942   -300.79164295     0.        ...
# 2026  [[  635.60482268  -300.93839604     0.        ...
# 2027  [[  635.91665096  -301.08514903     0.        ...
# ...

# %%
a = df['pos'].to_list()

# %%
import numpy as np
b=np.array(a)

# %%
b
# Out:
# array(['[[ 0.         -0.51639778  0.        ]\n [ 2.          1.03279556  0.        ]]',
#        '[[ 0.25       -1.03279556  0.        ]\n [ 1.5         2.06559112  0.        ]]',
#        '[[ 0.62352647 -1.45351014  0.        ]\n [ 0.75294706  2.90702029  0.        ]]',
#        ...,
#        '[[  635.91665096  -301.08514903     0.        ]\n [-1269.83330193   602.17029805     0.        ]]',
#        '[[  636.22847904  -301.23190192     0.        ]\n [-1270.45695809   602.46380384     0.        ]]',
#        '[[  636.54030692  -301.37865471     0.        ]\n [-1271.08061384   602.75730943     0.        ]]'],
#       dtype='<U96')
