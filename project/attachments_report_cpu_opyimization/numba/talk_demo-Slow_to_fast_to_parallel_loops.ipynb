# %% [markdown]
# ## Slow loops

# %% [markdown]
# Python loops are inefficient for numeric operations.

# %%
import numpy as np

# %% [markdown]
# Here's a function that computes the sum of the log of all non-zero values.

# %%
def sum_log_nz(ary):
    res = np.zeros(ary.shape[0])
    for i in range(ary.shape[0]):
        v = ary[i] 
        if v != 0:
            res[i] = np.log(v)
    return res.sum()

# %% [markdown]
# Test the function

# %%
a = np.random.random(5_000_000)

# %%
a
# Out:
# array([0.18467213, 0.33784349, 0.08921073, ..., 0.06290937, 0.97608245,
#        0.87281367])

# %%
sum_log_nz(a)
# Out:
# -4999748.670592799

# %% [markdown]
# Time the function

# %%
# %%time 
sum_log_nz(a)
# Out:
# CPU times: user 20.8 s, sys: 69.8 ms, total: 20.9 s
# Wall time: 21 s
# -4999748.670592799

# %% [markdown]
# ## SIMD Loops

# %% [markdown]
# Numba can compile the inefficient pure-Python loop into SIMD-vectorized native loop.

# %%
import numba

# %% [markdown]
# Try compiling the function with Numba.
#
# Notice the difference between settings of `fastmath=<True|False>`.

# %%
fast_sum_log_nz = numba.njit(fastmath=True)(sum_log_nz)
fast_sum_log_nz
# Out:
# CPUDispatcher(<function sum_log_nz at 0x7f378b8bd630>)

# %%
fast_sum_log_nz(a)
# Out:
# -4999748.67059264

# %% [markdown]
# Notice the improved performance

# %%
# %%time

fast_sum_log_nz(a)
# Out:
# CPU times: user 371 ms, sys: 28.6 ms, total: 400 ms
# Wall time: 371 ms
# -4999748.67059264

# %%
slow_sum_log_nz = numba.njit(fastmath=False)(sum_log_nz)

# %%
# %%time
slow_sum_log_nz(a)
# Out:
# CPU times: user 837 ms, sys: 15.5 ms, total: 853 ms
# Wall time: 859 ms
# -4999748.67059264

# %%
fast_sum_log_nz.inspect_cfg(fast_sum_log_nz.signatures[0]).display()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /ca23/ext_volume/project/talk_demo-Slow_to_fast_to_parallel_loops.ipynb Cella 22 line 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f627573795f726f62696e736f6e222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/ca23/ext_volume/project/talk_demo-Slow_to_fast_to_parallel_loops.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fast_sum_log_nz.inspect_cfg(fast_sum_log_nz.signatures[0]).display()
#
# File ~/miniconda3/lib/python3.10/site-packages/numba/core/codegen.py:507, in _CFG.display(self, filename, format, view)
#     497 def display(self, filename=None, format='pdf', view=False):
#     498     """
#     499     Plot the CFG.  In IPython notebook, the return image object can be
#     500     inlined.
#    (...)
#     505     be any valid format string accepted by graphviz, default is 'pdf'.
#     506     """
# --> 507     rawbyt = self.pretty_printer(filename=filename, view=view,
#     508                                  render_format=format, **self.kwargs)
#     509     return rawbyt.decode('utf-8')
#
# File ~/miniconda3/lib/python3.10/site-packages/numba/core/codegen.py:108, in _CFG.pretty_printer(self, filename, view, render_format, highlight, interleave, strip_ir, show_key, fontsize)
#      99 def pretty_printer(self, filename=None, view=None, render_format=None,
#     100                    highlight=True,
#     101                    interleave=False, strip_ir=False, show_key=True,
#     102                    fontsize=10):
#     103     """
#     104     "Pretty" prints the DOT graph of the CFG.
#     105     For explanation of the parameters see the docstring for
#     106     numba.core.dispatcher::inspect_cfg.
#     107     """
# --> 108     import graphviz as gv
#     109     import re
#     110     import json
#
# ModuleNotFoundError: No module named 'graphviz'

# %% [markdown]
# ## Parallel Loops

# %% [markdown]
# Numba can auto-parallize the function to leverage multiple threads.

# %%
par_sum_log_nz = numba.njit(parallel=True)(sum_log_nz)

# %%
par_sum_log_nz(a)
# Out:
# -4999748.670592664

# %% [markdown]
# Use the `.parallel_diagnostics()` to inspect what the compiler has done to optimize the function.
#
# Note:
# * notice how the manually written loop is not recognized.

# %%
par_sum_log_nz.parallel_diagnostics()
# Out:
#
# ================================================================================
#  Parallel Accelerator Optimizing:  Function sum_log_nz,
# /tmp/ipykernel_12394/958321262.py (1)
# ================================================================================
#
#
# Parallel loop listing for  Function sum_log_nz, /tmp/ipykernel_12394/958321262.py (1)
# -------------------------------------|loop #ID
# def sum_log_nz(ary):                 |
#     res = np.zeros(ary.shape[0])-----| #0
#     for i in range(ary.shape[0]):    |
#         v = ary[i]                   |
#         if v != 0:                   |
#             res[i] = np.log(v)       |
#     return res.sum()-----------------| #1
# ------------------------------ After Optimisation ------------------------------
# Parallel structure is already optimal.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# Use `numba.prange` to mark a loop for parallelization.

# %%
@numba.njit(parallel=True, fastmath=True)
def par_sum_log_nz(ary):
    res = np.zeros(ary.shape[0])
    for i in numba.prange(ary.shape[0]):
        v = ary[i] 
        if v != 0:
            res[i] = np.log(v)
    return res.sum()

# %%
par_sum_log_nz(a)
# Out:
# -4999748.670592664

# %%
# %%time
par_sum_log_nz(a)
# Out:
# CPU times: user 260 ms, sys: 38.2 ms, total: 298 ms
# Wall time: 112 ms
# -4999748.670592664

# %% [markdown]
# Compare the result of the `.parallel_diagnostics()` with the previous version.
#
# Note:
# * 3 loops are recognized.
# * the loops are fused because they iterate over the same domain.

# %%
par_sum_log_nz.parallel_diagnostics()
# Out:
#
# ================================================================================
#  Parallel Accelerator Optimizing:  Function par_sum_log_nz,
# /tmp/ipykernel_12394/1255685608.py (1)
# ================================================================================
#
#
# Parallel loop listing for  Function par_sum_log_nz, /tmp/ipykernel_12394/1255685608.py (1)
# ---------------------------------------------|loop #ID
# @numba.njit(parallel=True, fastmath=True)    |
# def par_sum_log_nz(ary):                     |
#     res = np.zeros(ary.shape[0])-------------| #2
#     for i in numba.prange(ary.shape[0]):-----| #4
#         v = ary[i]                           |
#         if v != 0:                           |
#             res[i] = np.log(v)               |
#     return res.sum()-------------------------| #3
# ------------------------------ After Optimisation ------------------------------
# Parallel region 0:
# +--2 (parallel, fused with loop(s): 3, 4)
#
#
#
# Parallel region 0 (loop #2) had 2 loop(s) fused.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
